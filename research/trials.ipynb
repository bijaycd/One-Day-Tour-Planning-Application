# %%
import sys
import os

# Adjust the path below to your project's root directory
project_root = os.path.abspath("..")  # Go one level up, assuming Jupyter is in 'src/tourplanner' folder
sys.path.append(project_root)

# %%
from src.tourplanner.agents.user_interaction_agent import collect_user_preferences

# Run the function and observe the responses
preferences = collect_user_preferences()
print("Collected Preferences:", preferences)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\site-packages\httpx\_transports\default.py:72, in map_httpcore_exceptions()
#      71 try:
# ---> 72     yield
#      73 except Exception as exc:
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\site-packages\httpx\_transports\default.py:236, in HTTPTransport.handle_request(self, request)
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\site-packages\httpcore\_sync\connection.py:99, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
# ---> 99     raise exc
#     101 return self._connection.handle_request(request)
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\site-packages\httpcore\_sync\connection.py:76, in HTTPConnection.handle_request(self, request)
#      75 if self._connection is None:
# ---> 76     stream = self._connect(request)
#      78     ssl_object = stream.get_extra_info("ssl_object")
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\site-packages\httpcore\_sync\connection.py:122, in HTTPConnection._connect(self, request)
#     121 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 122     stream = self._network_backend.connect_tcp(**kwargs)
#     123     trace.return_value = stream
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\site-packages\httpcore\_backends\sync.py:213, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     212         sock.setsockopt(*option)  # pragma: no cover
# --> 213     sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     214 return SyncStream(sock)
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\contextlib.py:135, in _GeneratorContextManager.__exit__(self, type, value, traceback)
#     134 try:
# --> 135     self.gen.throw(type, value, traceback)
#     136 except StopIteration as exc:
#     137     # Suppress StopIteration *unless* it's the same exception that
#     138     # was passed to throw().  This prevents a StopIteration
#     139     # raised inside the "with" statement from being suppressed.
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# Cell In[4], line 4
#       1 from src.tourplanner.agents.user_interaction_agent import collect_user_preferences
#       3 # Run the function and observe the responses
# ----> 4 preferences = collect_user_preferences()
#       5 print("Collected Preferences:", preferences)
#
# File c:\Projects\One-Day-Tour-Planning-Application\src\tourplanner\agents\user_interaction_agent.py:12, in collect_user_preferences()
#      10 # Ask for the city
#      11 city_prompt = "Which city would you like to explore?"
# ---> 12 preferences['city'] = generate_response(city_prompt).strip()
#      14 # Ask for the start time
#      15 start_time_prompt = "What time would you like to start your day? (e.g., 9:00 AM)"
#
# File c:\Projects\One-Day-Tour-Planning-Application\src\tourplanner\llm\llm_interface.py:15, in generate_response(prompt, model_name)
#       6 def generate_response(prompt, model_name='llama2'):
#       7     """
#       8     Generate a response from the Ollama model based on the provided prompt.
#       9     Args:
#    (...)
#      13         str: The generated text response from Ollama.
#      14     """
# ---> 15     response = client.chat(
#      16         model=model_name,
#      17         messages=[{'role': 'user', 'content': prompt}]
#      18     )
#      19     return response['message']['content']
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\site-packages\ollama\_client.py:236, in Client.chat(self, model, messages, tools, stream, format, options, keep_alive)
#     233   if images := message.get('images'):
#     234     message['images'] = [_encode_image(image) for image in images]
# --> 236 return self._request_stream(
#     237   'POST',
#     238   '/api/chat',
#     239   json={
#     240     'model': model,
#     241     'messages': messages,
#     242     'tools': tools or [],
#     243     'stream': stream,
#     244     'format': format,
#     245     'options': options or {},
#     246     'keep_alive': keep_alive,
#     247   },
#     248   stream=stream,
#     249 )
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\site-packages\ollama\_client.py:99, in Client._request_stream(self, stream, *args, **kwargs)
#      93 def _request_stream(
#      94   self,
#      95   *args,
#      96   stream: bool = False,
#      97   **kwargs,
#      98 ) -> Union[Mapping[str, Any], Iterator[Mapping[str, Any]]]:
# ---> 99   return self._stream(*args, **kwargs) if stream else self._request(*args, **kwargs).json()
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\site-packages\ollama\_client.py:70, in Client._request(self, method, url, **kwargs)
#      69 def _request(self, method: str, url: str, **kwargs) -> httpx.Response:
# ---> 70   response = self._client.request(method, url, **kwargs)
#      72   try:
#      73     response.raise_for_status()
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\site-packages\httpx\_client.py:837, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     822     warnings.warn(message, DeprecationWarning)
#     824 request = self.build_request(
#     825     method=method,
#     826     url=url,
#    (...)
#     835     extensions=extensions,
#     836 )
# --> 837 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\site-packages\httpx\_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\site-packages\httpx\_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\site-packages\httpx\_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\site-packages\httpx\_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\site-packages\httpx\_transports\default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\contextlib.py:135, in _GeneratorContextManager.__exit__(self, type, value, traceback)
#     133     value = type()
#     134 try:
# --> 135     self.gen.throw(type, value, traceback)
#     136 except StopIteration as exc:
#     137     # Suppress StopIteration *unless* it's the same exception that
#     138     # was passed to throw().  This prevents a StopIteration
#     139     # raised inside the "with" statement from being suppressed.
#     140     return exc is not value
#
# File c:\Projects\One-Day-Tour-Planning-Application\venv\lib\site-packages\httpx\_transports\default.py:89, in map_httpcore_exceptions()
#      86     raise
#      88 message = str(exc)
# ---> 89 raise mapped_exc(message) from exc
#
# ConnectError: [WinError 10061] No connection could be made because the target machine actively refused it
